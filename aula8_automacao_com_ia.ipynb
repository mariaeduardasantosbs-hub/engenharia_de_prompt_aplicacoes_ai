# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaeduardasantosbs-hub/engenharia_de_prompt_aplicacoes_ai/blob/main/aula8_automacao_com_ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Este é um script de exemplo para verificar a temperatura do sistema.
# Em um ambiente real, 'get_system_temperature' precisaria interagir com o hardware
# usando bibliotecas como 'psutil' ou específicas do sistema operacional.

def get_system_temperature():
    """
    Simula a obtenção da temperatura do sistema.
    Em um cenário real, esta função leria dados de sensores de hardware.
    """
    # Substitua este valor por uma leitura real do sensor de temperatura
    # Por exemplo: return psutil.sensors_temperatures()['cpu_thermal'][0].current
    return 35 # Temperatura de exemplo para testar o alerta


def check_temperature():
    temperature = get_system_temperature()
    print(f"Temperatura atual do sistema: {temperature}°C")

    if temperature > 30:
        print("ALERTA: Superaquecimento detectado! Temperatura acima de 30°C.")
    else:
        print("Temperatura do sistema está normal.")

# Executar a verificação da temperatura
check_temperature()
# Out:
# Temperatura atual do sistema: 35°C
# ALERTA: Superaquecimento detectado! Temperatura acima de 30°C.
